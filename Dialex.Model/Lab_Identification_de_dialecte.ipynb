# %% [markdown]
# # Utiliser data_v0.1.0.csv pour l'apprentissage et QADI_test_prepro_V0_1_1.csv pourle test
# * En utilisant la méthode value_counts() de Pandas, afficher le nombre d'occurences pour chaque dialect dans les bases d'apprentissage et de test

# %%
#df = pd.read_csv('data_v0.1.0.csv')
#test = pd.read_csv('/content/QADI_test_prepro_V0_1_1.csv')

# %% [markdown]
# # Pour visualiser les données:
# * Utiliser la bibliothèque  ar_wordcloud pour afficher le nuage des mots les plus fréquents pour les dialects Egyptien, Marocain et Saudi comme le montre les images.

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# # Pour créer un modèle d'identification de dialecte:
#
#
#  * Utiliser TF-IDF et des unigrams, bigrams et trigrams pour la vectorisation,
#
#  * Un classifieur Bayes Naif multinomial.
#  * Utiliser SKLEARN dans toutes les étapes.
#  * Utiliser la méthode dump de Pickle pour enregistrer le modèle obtenu

# %% [markdown]
# ![Capture d’écran 2025-03-19 à 10.34.47 a.m..png](data:image/png;base64,...)## Modeling

# %% [markdown]
# # Pour évaluer le modèle produit:
# * afficher la précision (accuracy) sur le test ainsi que la matrice de confusions.
# * Utiliser les méthodes de sklearn.metrics pour ce faire.

# %% [markdown]
# # Appliquer le modèle produit à une phrase du dialect marocain de votre choix.

# %% [markdown]
# # Ré-entrainer le modèle, cette fois-ci, après avoir traité les données. Pour ce faire:
#
# *   appliquer les étapes de préparation montrées ci-après.
# *   appliquer le même pipeline de modélisation aux nouvelles données.
# *   comparer les métriques d'évaluation et commenter.

# %% [markdown]
# ![Capture d’écran 2025-03-19 à 10.53.55 a.m..png](data:image/png;base64,...)
